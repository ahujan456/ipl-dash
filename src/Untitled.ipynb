# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\ipl-dashboard\data\deliveries.csv")
df_copy = pd.read_csv("D:\ipl-dashboard\data\deliveries.csv")

# %%
df.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
df['fielder'].value_counts()
# Out:
# fielder
# MS Dhoni            220
# KD Karthik          199
# AB de Villiers      141
# RV Uthappa          133
# WP Saha             131
#                    ...
# TS Mills              1
# Ankit Soni            1
# WPUJC Vaas            1
# B Laughlin            1
# T Kohler-Cadmore      1
# Name: count, Length: 607, dtype: int64

# %% [markdown]
# ## Dirty Data
#
# ### batting_team
# - Royal Challengers Bangalore & Royal Challengers Bengaluru
# - Rising Pune Supergiant & Rising Pune Supergiants
# ### same with bowling_team

# %%
tdf = df[df['batting_team'] == 'Royal Challengers Bengaluru']

# %%
df.loc[tdf.index, 'batting_team'] = 'Royal Challengers Bangalore'

# %%
tdf = df[df['batting_team'] == 'Rising Pune Supergiant']

# %%
df.loc[tdf.index, 'batting_team'] = 'Rising Pune Supergiants'

# %%
df['batting_team'].value_counts()
# Out:
# batting_team
# Mumbai Indians                 31437
# Royal Challengers Bangalore    30023
# Kolkata Knight Riders          29514
# Chennai Super Kings            28651
# Rajasthan Royals               26242
# Kings XI Punjab                22646
# Sunrisers Hyderabad            21843
# Delhi Daredevils               18786
# Delhi Capitals                 10946
# Deccan Chargers                 9034
# Punjab Kings                    6833
# Gujarat Titans                  5494
# Pune Warriors                   5443
# Lucknow Super Giants            5400
# Gujarat Lions                   3566
# Rising Pune Supergiants         3480
# Kochi Tuskers Kerala            1582
# Name: count, dtype: int64

# %%
tdf = df[df['bowling_team'] == 'Royal Challengers Bengaluru']

# %%
df.loc[tdf.index, 'bowling_team'] = 'Royal Challengers Bangalore'

# %%
tdf = df[df['bowling_team'] == 'Rising Pune Supergiant']

# %%
df.loc[tdf.index, 'batting_team'] = 'Rising Pune Supergiants'

# %%
df.to_csv("D:\ipl-dashboard\data\deliveries_edited.csv")

# %%
dfm = pd.read_csv('D:\ipl-dashboard\data\matches.csv')

# %%
dfm
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df_batter = df.groupby('batter')

# %%
# df_batter['player_of_match']

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df_batter['match_id'].value_counts()
# Out:
# batter          match_id
# A Ashish Reddy  980907      18
#                 598030      16
#                 829815      15
#                 598018      15
#                 598004      12
#                             ..
# Z Khan          1082595      1
#                 336006       1
#                 336026       1
#                 419146       1
#                 1082646      1
# Name: count, Length: 16515, dtype: int64

# %%
g_obj = df.groupby(['batter', 'match_id'])

# %%
df.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
g_obj.sum()['batsman_runs']['BB McCullum'].max()
# Out:
# 158

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
# ...

# %%
list(df_batter['batting_team'].unique()['MS Dhoni'])
# Out:
# ['Chennai Super Kings', 'Rising Pune Supergiants']

# %%
df_batter['batsman_runs']==6
# Out:
# False

# %%
df[df['is_wicket']==1].groupby('batter')['batter'].count()
# Out:
# batter
# A Ashish Reddy     15
# A Badoni           26
# A Chandila          1
# A Chopra            5
# A Choudhary         2
#                  ...
# Yashpal Singh       4
# Younis Khan         1
# Yudhvir Singh       4
# Yuvraj Singh      109
# Z Khan             15
# Name: batter, Length: 623, dtype: int64

# %%
df.groupby(['batter', 'batting_team'])['batsman_runs'].sum()['Yuvraj Singh']
# Out:
# batting_team
# Delhi Daredevils               248
# Kings XI Punjab                963
# Mumbai Indians                  98
# Pune Warriors                  581
# Rising Pune Supergiants         47
# Royal Challengers Bangalore    376
# Sunrisers Hyderabad            441
# Name: batsman_runs, dtype: int64

# %%
lab = df.groupby(['batter', 'batting_team'])['batsman_runs'].sum()['Yuvraj Singh'].index
fig, ax = plt.subplots()
vals = df.groupby(['batter', 'batting_team'])['batsman_runs'].sum()['Yuvraj Singh'].to_list()
ax.pie(vals, labels=lab, autopct='%1.1f%%')
plt.plot()
# Out:
# []

# %%
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...
